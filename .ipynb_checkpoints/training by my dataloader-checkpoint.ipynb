# %% [markdown]
# # Training by my dataloader

# %%
import numpy as np
import torch
from torch.autograd import Variable
from FuseNetClass import FuseNet, CrossEntropy2d
from SolverClass_FuseNet import Solver_SS
import torch.nn.functional as F
from utils.data_utils_class import get_data

import time

import h5py
import scipy.io 
import os

from NYUDv2Loader import *
# Out:
# [PROGRESS] Chosen GPU Device: 0

# %%
############################################################################
#                                TRAIN                                     #
############################################################################

resume = False
dset_type = 'NYU'
t_loader = NYUDv2Loader('/home/dongwonshin/Desktop/Datasets/NYUDv2/', split='training')
v_loader = NYUDv2Loader('/home/dongwonshin/Desktop/Datasets/NYUDv2/', split='val')

train_loader = data.DataLoader(t_loader, batch_size=4, num_workers=16, shuffle=True)
val_loader = data.DataLoader(v_loader, batch_size=4, num_workers=16)
# Out:
# [PROGRESS] NYU dataset retrieved
# 164
# [PROGRESS] Selected Training Mode: NEW
# [PROGRESS] TRAINING STARTS
# []
# []
# []
# []
# []
# /home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# /home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# /home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# /home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# /home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# /home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# /home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# /home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# /home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# /home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# /home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# /home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# /home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# /home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# /home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# /home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# Process Process-2:
# Traceback (most recent call last):
# Process Process-12:
# Process Process-14:
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
# Traceback (most recent call last):
#     self.run()
# Process Process-10:
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
# Traceback (most recent call last):
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 114, in run
# Traceback (most recent call last):
#     self.run()
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#     self._target(*self._args, **self._kwargs)
#     self.run()
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 114, in run
# Process Process-8:
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/utils/data/dataloader.py", line 57, in _worker_loop
#     self.run()
#     self._target(*self._args, **self._kwargs)
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 114, in run
# Traceback (most recent call last):
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/utils/data/dataloader.py", line 57, in _worker_loop
# Process Process-3:
#     self._target(*self._args, **self._kwargs)
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "NYUDv2Loader.py", line 74, in __getitem__
#     self._target(*self._args, **self._kwargs)
# Process Process-13:
#     samples = collate_fn([dataset[i] for i in batch_indices])
# Process Process-6:
# Traceback (most recent call last):
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/utils/data/dataloader.py", line 57, in _worker_loop
#   File "NYUDv2Loader.py", line 74, in __getitem__
#     label_img = transform.resize(label_img, (self.img_size[0], self.img_size[1]))
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/utils/data/dataloader.py", line 57, in _worker_loop
#     self.run()
#     label_img = transform.resize(label_img, (self.img_size[0], self.img_size[1]))
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py", line 169, in resize
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py", line 169, in resize
#   File "NYUDv2Loader.py", line 57, in __getitem__
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self.run()
#     self.run()
#   File "NYUDv2Loader.py", line 72, in __getitem__
#     preserve_range=preserve_range)
#     self.run()
#     color_img = io.imread(color_path)
#     preserve_range=preserve_range)
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 114, in run
#     color_img = transform.resize(color_img, (self.img_size[0], self.img_size[1]))
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/io/_io.py", line 62, in imread
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py", line 851, in warp
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py", line 894, in warp
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py", line 169, in resize
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/utils/data/dataloader.py", line 57, in _worker_loop
#     warped = np.dstack(dims)
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/utils/data/dataloader.py", line 57, in _worker_loop
#     _clip_warp_output(image, warped, order, mode, cval, clip)
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/utils/data/dataloader.py", line 57, in _worker_loop
#     preserve_range=preserve_range)
#     self._target(*self._args, **self._kwargs)
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/numpy/lib/shape_base.py", line 421, in dstack
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py", line 655, in _clip_warp_output
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py", line 850, in warp
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/utils/data/dataloader.py", line 57, in _worker_loop
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "NYUDv2Loader.py", line 72, in __getitem__
#     np.clip(output_image, min_val, max_val, out=output_image)
#   File "NYUDv2Loader.py", line 74, in __getitem__
#     order=order, mode=mode, cval=cval))
#   File "NYUDv2Loader.py", line 72, in __getitem__
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/numpy/core/fromnumeric.py", line 1775, in clip
#     color_img = transform.resize(color_img, (self.img_size[0], self.img_size[1]))
#     label_img = transform.resize(label_img, (self.img_size[0], self.img_size[1]))
#   File "skimage/transform/_warps_cy.pyx", line 131, in skimage.transform._warps_cy._warp_fast
#     color_img = transform.resize(color_img, (self.img_size[0], self.img_size[1]))
#   File "NYUDv2Loader.py", line 74, in __getitem__
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py", line 169, in resize
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py", line 169, in resize
# Process Process-11:
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/numpy/core/numeric.py", line 424, in asarray
#     preserve_range=preserve_range)
#     label_img = transform.resize(label_img, (self.img_size[0], self.img_size[1]))
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py", line 169, in resize
#     preserve_range=preserve_range)
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py", line 850, in warp
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py", line 169, in resize
#     preserve_range=preserve_range)
#     order=order, mode=mode, cval=cval))
#     img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#     self.run()
#     preserve_range=preserve_range)
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py", line 850, in warp
#   File "skimage/transform/_warps_cy.pyx", line 131, in skimage.transform._warps_cy._warp_fast
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/io/manage_plugins.py", line 214, in call_plugin
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py", line 851, in warp
#     order=order, mode=mode, cval=cval))
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/numpy/core/numeric.py", line 424, in asarray
#     self._target(*self._args, **self._kwargs)
#     return func(*args, **kwargs)
#     warped = np.dstack(dims)
#   File "skimage/transform/_warps_cy.pyx", line 131, in skimage.transform._warps_cy._warp_fast
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/io/_plugins/pil_plugin.py", line 36, in imread
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/utils/data/dataloader.py", line 57, in _worker_loop
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/numpy/core/numeric.py", line 424, in asarray
#     im = Image.open(f)
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/PIL/Image.py", line 2589, in open
#   File "NYUDv2Loader.py", line 74, in __getitem__
#     label_img = transform.resize(label_img, (self.img_size[0], self.img_size[1]))
#     return _nx.concatenate([atleast_3d(_m) for _m in tup], 2)
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py", line 169, in resize
# KeyboardInterrupt
#     preserve_range=preserve_range)
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/numpy/lib/shape_base.py", line 421, in dstack
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py", line 851, in warp
#     return _nx.concatenate([atleast_3d(_m) for _m in tup], 2)
#     warped = np.dstack(dims)
# KeyboardInterrupt
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/numpy/lib/shape_base.py", line 421, in dstack
#     return _nx.concatenate([atleast_3d(_m) for _m in tup], 2)
# KeyboardInterrupt
#     return _wrapfunc(a, 'clip', a_min, a_max, out=out)
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/numpy/core/fromnumeric.py", line 52, in _wrapfunc
#     return getattr(obj, method)(*args, **kwds)
# KeyboardInterrupt
# Process Process-15:
#     def asarray(a, dtype=None, order=None):
#     def asarray(a, dtype=None, order=None):
#     def asarray(a, dtype=None, order=None):
# KeyboardInterrupt
# KeyboardInterrupt
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#     self.run()
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/utils/data/dataloader.py", line 57, in _worker_loop
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "NYUDv2Loader.py", line 74, in __getitem__
#     label_img = transform.resize(label_img, (self.img_size[0], self.img_size[1]))
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py", line 169, in resize
#     preserve_range=preserve_range)
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py", line 851, in warp
#     warped = np.dstack(dims)
# Process Process-4:
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/numpy/lib/shape_base.py", line 421, in dstack
# Traceback (most recent call last):
#     return _nx.concatenate([atleast_3d(_m) for _m in tup], 2)
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#     prefix = fp.read(16)
# KeyboardInterrupt
#     self.run()
# KeyboardInterrupt
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/utils/data/dataloader.py", line 57, in _worker_loop
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "NYUDv2Loader.py", line 74, in __getitem__
#     label_img = transform.resize(label_img, (self.img_size[0], self.img_size[1]))
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py", line 169, in resize
#     preserve_range=preserve_range)
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py", line 851, in warp
#     warped = np.dstack(dims)
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/numpy/lib/shape_base.py", line 421, in dstack
#     return _nx.concatenate([atleast_3d(_m) for _m in tup], 2)
# KeyboardInterrupt
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# Process Process-1:
# Traceback (most recent call last):
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#     self.run()
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/utils/data/dataloader.py", line 57, in _worker_loop
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "NYUDv2Loader.py", line 74, in __getitem__
#     label_img = transform.resize(label_img, (self.img_size[0], self.img_size[1]))
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py", line 169, in resize
#     preserve_range=preserve_range)
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py", line 851, in warp
#     warped = np.dstack(dims)
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/numpy/lib/shape_base.py", line 421, in dstack
#     return _nx.concatenate([atleast_3d(_m) for _m in tup], 2)
# KeyboardInterrupt
# Process Process-5:
#     self.run()
# Traceback (most recent call last):
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/IPython/core/ultratb.py", line 1132, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/IPython/core/ultratb.py", line 313, in wrapped
#     return f(*args, **kwargs)
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/IPython/core/ultratb.py", line 358, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/inspect.py", line 1051, in getinnerframes
#     framelist.append((tb.tb_frame,) + getframeinfo(tb, context))
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/inspect.py", line 1011, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/inspect.py", line 453, in getsourcefile
#     if hasattr(getmodule(object, filename), '__loader__'):
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/inspect.py", line 499, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/utils/data/dataloader.py", line 178, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 16493) exited unexpectedly with exit code 1.
# Traceback (most recent call last):
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#     self.run()
# Process Process-7:
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/utils/data/dataloader.py", line 57, in _worker_loop
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "NYUDv2Loader.py", line 74, in __getitem__
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 114, in run
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_code(self, code_obj, result)
#    2893             if result is not None:
#    2894                 result.error_in_exec = sys.exc_info()[1]
# -> 2895             self.showtraceback()
#    2896         else:
#    2897             outflag = 0
#
# /home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in showtraceback(self, exc_tuple, filename, tb_offset, exception_only)
#    1824                     except Exception:
#    1825                         stb = self.InteractiveTB.structured_traceback(etype,
# -> 1826                                             value, tb, tb_offset=tb_offset)
#    1827
#    1828                     self._showtraceback(etype, value, stb)
#
# /home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/IPython/core/ultratb.pyc in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1409         self.tb = tb
#    1410         return FormattedTB.structured_traceback(
# -> 1411             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1412
#    1413
#
# /home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/IPython/core/ultratb.pyc in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1317             # Verbose modes need a full traceback
#    1318             return VerboseTB.structured_traceback(
# -> 1319                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1320             )
#    1321         else:
#
# /home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/IPython/core/ultratb.pyc in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1202                 structured_traceback_parts += formatted_exception
#    1203         else:
# -> 1204             structured_traceback_parts += formatted_exception[0]
#    1205
#    1206         return structured_traceback_parts
#
# IndexError: string index out of range
#     label_img = transform.resize(label_img, (self.img_size[0], self.img_size[1]))
#     self._target(*self._args, **self._kwargs)
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py", line 169, in resize
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/utils/data/dataloader.py", line 57, in _worker_loop
#     preserve_range=preserve_range)
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py", line 851, in warp
#     samples = collate_fn([dataset[i] for i in batch_indices])
#     warped = np.dstack(dims)
#   File "NYUDv2Loader.py", line 74, in __getitem__
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/numpy/lib/shape_base.py", line 421, in dstack
#     label_img = transform.resize(label_img, (self.img_size[0], self.img_size[1]))
#     return _nx.concatenate([atleast_3d(_m) for _m in tup], 2)
# KeyboardInterrupt
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py", line 169, in resize
#     preserve_range=preserve_range)
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py", line 851, in warp
#     warped = np.dstack(dims)
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/numpy/lib/shape_base.py", line 421, in dstack
#     return _nx.concatenate([atleast_3d(_m) for _m in tup], 2)
# KeyboardInterrupt
# Process Process-9:
# Traceback (most recent call last):
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#     self.run()
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/utils/data/dataloader.py", line 57, in _worker_loop
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "NYUDv2Loader.py", line 74, in __getitem__
#     label_img = transform.resize(label_img, (self.img_size[0], self.img_size[1]))
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py", line 169, in resize
#     preserve_range=preserve_range)
# Process Process-16:
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py", line 851, in warp
# Traceback (most recent call last):
#     warped = np.dstack(dims)
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/numpy/lib/shape_base.py", line 421, in dstack
#     self.run()
#     return _nx.concatenate([atleast_3d(_m) for _m in tup], 2)
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/utils/data/dataloader.py", line 57, in _worker_loop
# KeyboardInterrupt
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "NYUDv2Loader.py", line 74, in __getitem__
#     label_img = transform.resize(label_img, (self.img_size[0], self.img_size[1]))
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py", line 169, in resize
#     preserve_range=preserve_range)
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/skimage/transform/_warps.py", line 851, in warp
#     warped = np.dstack(dims)
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/numpy/lib/shape_base.py", line 421, in dstack
#     return _nx.concatenate([atleast_3d(_m) for _m in tup], 2)
# KeyboardInterrupt

# %%
print ("[PROGRESS] %s dataset retrieved"  %(dset_type))

model = FuseNet(14).cuda()

solver = Solver_SS(optim_args={"lr":5e-3, "weight_decay": 0.0005}, loss_func=CrossEntropy2d)
solver.train(model, 0.0004, dset_type, train_loader, val_loader, resume, log_nth=5, num_epochs=300)
