# %% [markdown]
# # SUNRGBD_HHA training

# %%
import sys
sys.path.insert(0, '../')
sys.path.insert(0, '../dataloaders')

import numpy as np
import torch
from torch.autograd import Variable
from FuseNet import FuseNet, CrossEntropy2d
from Solver_FuseNet import Solver_SS
import torch.nn.functional as F
from utils.data_utils_class import get_data

import time

import h5py
import scipy.io 
import os

from SUNRGBDLoader_HHA import *

# %%
############################################################################
#                                TRAIN                                     #
############################################################################

resume = False
gpu_device = 2
dset_type = 'SUN'
num_classes = 38
is_HHA = True

t_loader = SUNRGBDLoader_HHA(gpu_device, '/home/dongwonshin/Desktop/Datasets/SUNRGBD/SUNRGBD/', split='training', 
                        is_transform=True, img_norm=True, img_size=(240,320))
v_loader = SUNRGBDLoader_HHA(gpu_device, '/home/dongwonshin/Desktop/Datasets/SUNRGBD/SUNRGBD/', split='val', 
                        is_transform=True, img_norm=True, img_size=(240,320))

train_loader = data.DataLoader(t_loader, batch_size=4, num_workers=16, shuffle=True)
val_loader = data.DataLoader(v_loader, batch_size=4, num_workers=16)

# %%
print ("[PROGRESS] %s dataset retrieved"  %(dset_type))

model = FuseNet(gpu_device, num_classes, is_HHA)

solver = Solver_SS(gpu_device, is_HHA, optim_args={"lr":5e-3, "weight_decay": 0.0005}, loss_func=CrossEntropy2d)
solver.train(model, dset_type, train_loader, val_loader, resume, log_nth=5, num_epochs=300)
# Out:
# [PROGRESS] SUN dataset retrieved
# 0
# [PROGRESS] Selected Training Mode: NEW
# [PROGRESS] TRAINING STARTS
# Process Process-45:
# Process Process-41:
# Process Process-35:
# Process Process-40:
# Process Process-44:
# Process Process-39:
# Process Process-34:
# Process Process-42:
# Process Process-37:
# Process Process-38:
# Process Process-43:
# Process Process-36:
# Process Process-33:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
# Traceback (most recent call last):
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#     self.run()
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#     self.run()
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#     self.run()
#     self.run()
#     self.run()
#     self.run()
#     self.run()
#     self.run()
#     self.run()
#     self.run()
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self.run()
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self.run()
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self.run()
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/utils/data/dataloader.py", line 52, in _worker_loop
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/utils/data/dataloader.py", line 52, in _worker_loop
#     self._target(*self._args, **self._kwargs)
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/utils/data/dataloader.py", line 52, in _worker_loop
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/utils/data/dataloader.py", line 52, in _worker_loop
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/utils/data/dataloader.py", line 52, in _worker_loop
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/utils/data/dataloader.py", line 52, in _worker_loop
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/utils/data/dataloader.py", line 52, in _worker_loop
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/utils/data/dataloader.py", line 52, in _worker_loop
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/utils/data/dataloader.py", line 52, in _worker_loop
#     r = index_queue.get()
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/utils/data/dataloader.py", line 52, in _worker_loop
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/utils/data/dataloader.py", line 52, in _worker_loop
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/utils/data/dataloader.py", line 52, in _worker_loop
#     r = index_queue.get()
#     r = index_queue.get()
#     r = index_queue.get()
#     r = index_queue.get()
#     r = index_queue.get()
#     r = index_queue.get()
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/queues.py", line 376, in get
#     r = index_queue.get()
#     r = index_queue.get()
#     r = index_queue.get()
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/queues.py", line 376, in get
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/queues.py", line 376, in get
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/utils/data/dataloader.py", line 52, in _worker_loop
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/queues.py", line 376, in get
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/queues.py", line 376, in get
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/queues.py", line 376, in get
#     r = index_queue.get()
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/queues.py", line 376, in get
#     return recv()
#     r = index_queue.get()
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/queues.py", line 376, in get
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/queues.py", line 376, in get
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/queues.py", line 376, in get
#     return recv()
#     return recv()
#     r = index_queue.get()
#     return recv()
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/queues.py", line 376, in get
#     return recv()
#     return recv()
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/multiprocessing/queue.py", line 21, in recv
#     return recv()
#     return recv()
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/queues.py", line 376, in get
#     return recv()
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/multiprocessing/queue.py", line 21, in recv
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/queues.py", line 376, in get
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/multiprocessing/queue.py", line 21, in recv
#     return recv()
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/multiprocessing/queue.py", line 21, in recv
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/multiprocessing/queue.py", line 21, in recv
#     return recv()
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/multiprocessing/queue.py", line 21, in recv
#     buf = self.recv_bytes()
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/multiprocessing/queue.py", line 21, in recv
#     return recv()
#     buf = self.recv_bytes()
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/multiprocessing/queue.py", line 21, in recv
#     buf = self.recv_bytes()
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/multiprocessing/queue.py", line 21, in recv
#     buf = self.recv_bytes()
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/multiprocessing/queue.py", line 21, in recv
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/multiprocessing/queue.py", line 21, in recv
#     return recv()
#     buf = self.recv_bytes()
# KeyboardInterrupt
#     buf = self.recv_bytes()
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/multiprocessing/queue.py", line 21, in recv
# KeyboardInterrupt
#     buf = self.recv_bytes()
#     buf = self.recv_bytes()
# KeyboardInterrupt
# KeyboardInterrupt
#     buf = self.recv_bytes()
#     buf = self.recv_bytes()
# KeyboardInterrupt
#   File "/home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/multiprocessing/queue.py", line 21, in recv
# KeyboardInterrupt
# KeyboardInterrupt
#     buf = self.recv_bytes()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#     buf = self.recv_bytes()
# KeyboardInterrupt
#     buf = self.recv_bytes()
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-1541c9702cad> in <module>()
#       4
#       5 solver = Solver_SS(gpu_device, is_HHA, optim_args={"lr":5e-3, "weight_decay": 0.0005}, loss_func=CrossEntropy2d)
# ----> 6 solver.train(model, dset_type, train_loader, val_loader, resume, log_nth=5, num_epochs=300)
#
# /home/dongwonshin/Desktop/FuseNet_PyTorch/Solver_FuseNet.pyc in train(self, model, dset_type, train_loader, val_loader, resume, num_epochs, log_nth)
#     135
#     136             model.train()
# --> 137             for i, data in enumerate(train_loader, 0):
#     138                 timestep2 = time()
#     139                 rgb_inputs  = Variable(data[0].cuda(self.gpu_device))
#
# /home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/utils/data/dataloader.pyc in __iter__(self)
#     449
#     450     def __iter__(self):
# --> 451         return _DataLoaderIter(self)
#     452
#     453     def __len__(self):
#
# /home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/torch/utils/data/dataloader.pyc in __init__(self, loader)
#     237             for w in self.workers:
#     238                 w.daemon = True  # ensure that the worker exits on process exit
# --> 239                 w.start()
#     240
#     241             _update_worker_pids(id(self), tuple(w.pid for w in self.workers))
#
# /home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/process.pyc in start(self)
#     128         else:
#     129             from .forking import Popen
# --> 130         self._popen = Popen(self)
#     131         # Avoid a refcycle if the target function holds an indirect
#     132         # reference to the process object (see bpo-30775)
#
# /home/dongwonshin/.conda/envs/fusenet/lib/python2.7/multiprocessing/forking.pyc in __init__(self, process_obj)
#     119             self.returncode = None
#     120
# --> 121             self.pid = os.fork()
#     122             if self.pid == 0:
#     123                 if 'random' in sys.modules:
#
# KeyboardInterrupt:
