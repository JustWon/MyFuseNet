# %%
import sys
sys.path.insert(0, '../')

import numpy as np
import torch
from torch.autograd import Variable
from FuseNet import FuseNet, CrossEntropy2d
from Solver_FuseNet import Solver_SS
import torch.nn.functional as F
from utils.data_utils_class import get_data

from dataloaders.NYUDv2Loader import *
from dataloaders.SUNRGBDLoader import *

# %matplotlib inline
from utils.visual_utils import *

# %load_ext autoreload
# %autoreload 2

# %%
def evaluate(model, num_classes, val_loader):
    # Calculate IoU and Mean accuracies
    print num_classes
    val_confusion = np.zeros((num_classes,3))
    IoU = 0
    mean_acc = 0

    for batch in val_loader:
        val_rgb_inputs  = Variable(batch[0].cuda(gpu_device))
        val_d_inputs    = Variable(batch[1].cuda(gpu_device))
        val_labels      = Variable(batch[2].cuda(gpu_device))
        val_outputs     = model(val_rgb_inputs, val_d_inputs)
        _, val_preds    = torch.max	(val_outputs, 1)

        val_labels = val_labels - 1     # sun
#         val_preds = val_preds + 1       # nyu

        for i in range(num_classes):
            val_labels_mask = val_labels == i
            val_preds_mask = val_preds == i
            TP = np.sum((val_preds == val_labels)[val_labels_mask].data.cpu().numpy())
            #print TP
            val_confusion[i,0] += TP 
            val_confusion[i,1] += np.sum((val_labels==val_labels)[val_labels_mask].data.cpu().numpy()) - TP 
            val_confusion[i,2] += np.sum((val_preds==val_preds)[val_preds_mask].data.cpu().numpy()) - TP 

    for i in range(num_classes):
        TP, FP, FN = val_confusion[i]
        print(TP+FP,FN)
        IoU += TP / (TP + FP + FN)
        mean_acc += TP / (TP + FP)
    IoU /= num_classes
    mean_acc /= num_classes

    print("        Best VALIDATION IoU: %.3f Mean Accuracy: %.3f" % (IoU, mean_acc))

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [20, 10]

# %%
data_visualizer = DataVisualizer()

# %% [markdown]
# # NYUDv2

# %%
gpu_device = 2
num_classes_nyu = 14

# %%
v_loader_nyu = NYUDv2Loader(gpu_device, '/home/dongwonshin/Desktop/Datasets/NYUDv2/', split='val', is_transform=True, img_norm=True, img_size=(240,320))
val_loader_nyu = data.DataLoader(v_loader_nyu, batch_size=4, num_workers=16)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-f67fc2f81053> in <module>()
#       1 v_loader_nyu = NYUDv2Loader(gpu_device, '/home/dongwonshin/Desktop/Datasets/NYUDv2/', split='val', is_transform=True, img_norm=True, img_size=(240,320))
# ----> 2 val_loader_nyu = data.DataLoader(v_loader_nyu, batch_size=4, num_workers=16)
#
# AttributeError: 'list' object has no attribute 'DataLoader'

# %%
model_nyu = FuseNet(gpu_device, num_classes_nyu).cuda()
checkpoint = torch.load('../models/by my dataloader/nyu/checkpoint25.pth.tar')
model_nyu.load_state_dict(checkpoint['state_dict'])

# %%
for sample in val_loader_nyu:

    rgb_inputs  = Variable(sample[0].cuda(gpu_device))
    d_inputs    = Variable(sample[1].cuda(gpu_device))
    labels      = Variable(sample[2].cuda(gpu_device))
    val_outputs     = model_nyu(rgb_inputs, d_inputs)
    _, val_preds    = torch.max	(val_outputs, 1)
    
    val_preds = val_preds + 1
    
    print(np.unique(labels))
    break;
# Out:
# [ 0  3  4  5  6  7  8  9 10 12 13]
# Exception NameError: "global name 'FileNotFoundError' is not defined" in <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7f97cf695590>> ignored

# %%
idx = 0
data_visualizer.visualize_all(rgb_inputs[idx], d_inputs[idx], labels[idx], val_preds[idx], 
                              unnormalized_color=True, unnormalized_depth=True)

# %%
evaluate(model_nyu, num_classes_nyu, val_loader_nyu)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-576ebd94ba01> in <module>()
# ----> 1 evaluate(model_nyu, num_classes_nyu, val_loader_nyu)
#
# NameError: name 'model_nyu' is not defined

# %% [markdown]
# # SUNRGBD

# %%
num_classes_sun = 40

# %%
v_loader_sun = SUNRGBDLoader(gpu_device, '/home/dongwonshin/Desktop/Datasets/SUNRGBD/SUNRGBD/', split='val', is_transform=True, img_norm=True, img_size=(240,320))
val_loader_sun = data.DataLoader(v_loader_sun, batch_size=4, num_workers=16)

# %%
model_sun = FuseNet(gpu_device, num_classes_sun).cuda()
checkpoint = torch.load('../models/sun/checkpoint25.pth.tar')
model_sun.load_state_dict(checkpoint['state_dict'])

# %%
for sample in val_loader_sun:

    rgb_inputs  = Variable(sample[0].cuda(gpu_device))
    d_inputs    = Variable(sample[1].cuda(gpu_device))
    labels      = Variable(sample[2].cuda(gpu_device))
    val_outputs     = model_sun(rgb_inputs, d_inputs)
    _, val_preds    = torch.max	(val_outputs, 1)
    
    labels = labels - 1
    
    print(np.unique(labels))
    print(np.unique(val_preds))
    break;
# Out:
# [ 0  1  2  4  6  7  9 11 14 17 18 19 22 32 35 37]
# [0 1 2 4 5 7]
# Exception NameError: "global name 'FileNotFoundError' is not defined" in <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7fd21f064f50>> ignored

# %%
idx = 2
data_visualizer.visualize_all(rgb_inputs[idx], d_inputs[idx], labels[idx], val_preds[idx], unnormalized_color=True, unnormalized_depth=True)

# %%
evaluate(model_sun, num_classes_sun, val_loader_sun)
# Out:
# 40
# (0.0, 0.0)
# (100380819.0, 87123811.0)
# (76950380.0, 60721137.0)
# (66248050.0, 22065127.0)
# (8192273.0, 0.0)
# (8423890.0, 22599.0)
# (30644096.0, 15800178.0)
# (8244155.0, 0.0)
# (24590411.0, 6963021.0)
# (8046135.0, 0.0)
# (8101946.0, 0.0)
# (2579317.0, 0.0)
# (2263473.0, 0.0)
# (2701786.0, 0.0)
# (1273099.0, 0.0)
# (9681808.0, 0.0)
# (1101587.0, 0.0)
# (3573950.0, 0.0)
# (1858656.0, 0.0)
# (1627987.0, 0.0)
# (1528022.0, 0.0)
# (190924.0, 0.0)
# (1306164.0, 0.0)
# (3125932.0, 42.0)
# (1578584.0, 0.0)
# (1543665.0, 0.0)
# (552957.0, 0.0)
# (1227810.0, 0.0)
# (579606.0, 0.0)
# (154372.0, 0.0)
# (2292851.0, 0.0)
# (2034632.0, 0.0)
# (330616.0, 0.0)
# (192364.0, 0.0)
# (979421.0, 0.0)
# (1372099.0, 0.0)
# (762264.0, 0.0)
# (602312.0, 0.0)
# (924787.0, 0.0)
# (0.0, 0.0)
#         Best VALIDATION IoU: nan Mean Accuracy: nan
# /home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/ipykernel/__main__.py:30: RuntimeWarning: invalid value encountered in double_scalars
# /home/dongwonshin/.conda/envs/fusenet/lib/python2.7/site-packages/ipykernel/__main__.py:31: RuntimeWarning: invalid value encountered in double_scalars
